# %%
from natal import Data, Stats, Chart, Config
from datetime import datetime
from IPython.display import HTML

# %%
# Birth Chart

mimi = Data(
    name = "MiMi",
    city = "Taipei",
    dt = "1980-04-20 14:30",
    config = Config(theme_type="light")
)

chart = Chart(data1=mimi, width=600)
HTML(chart.svg)
# Out:
# <svg height="600" width="600" font-family="sans-serif" version="1.1" xmlns="http://www.w3.org/2000/svg"><circle cx="300.0" cy="300.0" r="270.0" fill="#FFFDF1" /><path d="M300.0 300.0 L553.25 206.37 A270.0 270.0 0 0 0 472.5 92.29 Z" fill="#fdeae4" stroke="#758492" stroke-width="1" stroke-opacity="1"></path><path d="M300.0 300.0 L472.5 92.29 A270.0 270.0 0 0 0 345.54 33.87 Z" fill="#fff8e3" stroke="#758492" stroke-width="1" stroke-opacity="1"></path><path d="M300.0 300.0 L345.54 33.87 A270.0 270.0 0 0 0 206.37 46.75 Z" fill="#e6f9e8" stroke="#758492" stroke-width="1" stroke-opacity="1"></path><path d="M300.0 300.0 L206.37 46.75 A270.0 270.0 0 0 0 92.29 127.5 Z" fill="#f2f6f0" stroke="#758492" stroke-width="1" stroke-opacity="1"></path><path d="M300.0 300.0 L92.29 127.5 A270.0 270.0 0 0 0 33.87 254.46 Z" fill="#fdeae4" stroke="#758492" stroke-width="1" stroke-opacity="1"></path><path d="M300.0 300.0 L33.87 254.46 A270.0 270.0 0 0 0 46.75 393.63 Z" fill="#fff8e3" stroke="#758492" stroke-width="1" stroke-opacity="1"></path><path d="M300.0 300.0 L46.75 393.63 A270.0 270.0 0 0 0 127.5 507.71 Z" fill="#e6f9e8" stroke="#758492" stroke-width="1" stroke-opacity="1"></path><path d="M300.0 300.0 L127.5 507.71 A270.0 270.0 0 0 0 254.46 566.13 Z" fill="#f2f6f0" stroke="#758492" stroke-width="1" stroke-opacity="1"></path><path d="M300.0 300.0 L254.46 566.13 A270.0 270.0 0 0 0 393.63 553.25 Z" fill="#fdeae4" stroke="#758492" stroke-width="1" stroke-opacity="1"></path><path d="M300.0 300.0 L393.63 553.25 A270.0 270.0 0 0 0 507.71 472.5 Z" fill="#fff8e3" stroke="#758492" stroke-width="1" stroke-opacity="1"></path><path d="M300.0 300.0 L507.71 472.5 A270.0 270.0 0 0 0 566.13 345.54 Z" fill="#e6f9e8" stroke="#758492" stroke-width="1" stroke-opacity="1"></path><path d="M300.0 300.0 L566.13 345.54 A270.0 270.0 0 0 0 553.25 206.37 Z" fill="#f2f6f0" stroke="#758492" stroke-width="1" stroke-opacity="1"></path><circle cx="300.0" cy="300.0" r="229.5" fill="#FFFDF1" /><path d="M300.0 300.0 L70.5 299.96 A229.5 229.5 0 0 0 96.45 406.01 Z" fill="#fdeae4" stroke="#758492" stroke-width="1" stroke-opacity="1"></path><text x="96.74670934464947" y="349.7359260270843" fill="#ef476f" font-size="17.820000000000004" text-anchor="middle" dominant-baseline="central">1</text><path d="M300.0 300.0 L96.45 406.01 A229.5 229.5 0 0 0 178.15 494.48 Z" fill="#fff8e3" stroke="#758492" stroke-width="1" stroke-opacity="1"></path><text x="146.26877139164426" y="441.95869769255233" fill="#ffd166" font-size="17.820000000000004" text-anchor="middle" dominant-baseline="central">2</text><path d="M300.0 300.0 L178.15 494.48 A229.5 229.5 0 0 0 298.04 529.49 Z" fill="#e6f9e8" stroke="#758492" stroke-width="1" stroke-opacity="1"></path><text x="241.3407521164669" y="500.85978974831727" fill="#06d6a0" font-size="17.820000000000004" text-anchor="middle" dominant-baseline="central">3</text><path d="M300.0 300.0 L298.04 529.49 A229.5 229.5 0 0 0 417.24 497.3 Z" fill="#f2f6f0" stroke="#758492" stroke-width="1" stroke-opacity="1"></path><text x="354.56360874710276" y="502.01082916639166" fill="#81bce7" font-size="17.820000000000004" text-anchor="middle" dominant-baseline="central">4</text><path d="M300.0 300.0 L417.24 497.3 A229.5 229.5 0 0 0 500.78 411.16 Z" fill="#fdeae4" stroke="#758492" stroke-width="1" stroke-opacity="1"></path><text x="450.2044846078006" y="445.6851924654835" fill="#ef476f" font-size="17.820000000000004" text-anchor="middle" dominant-baseline="central">5</text><path d="M300.0 300.0 L500.78 411.16 A229.5 229.5 0 0 0 529.5 300.04 Z" fill="#fff8e3" stroke="#758492" stroke-width="1" stroke-opacity="1"></path><text x="502.594074221901" y="352.35650475510073" fill="#ffd166" font-size="17.820000000000004" text-anchor="middle" dominant-baseline="central">6</text><path d="M300.0 300.0 L529.5 300.04 A229.5 229.5 0 0 0 503.55 193.99 Z" fill="#e6f9e8" stroke="#758492" stroke-width="1" stroke-opacity="1"></path><text x="503.2532906553505" y="250.2640739729157" fill="#06d6a0" font-size= ...

# %%
# transit chart
from natal.config import Orb

mimi.config.theme_type="dark"
mimi.config.orb = Orb(conjunction=2, opposition=2, square=2, trine=2, sextile=1)

current = Data(name="Current", city="Taipei", dt=datetime.now())

chart = Chart(data1=mimi, data2=current, width=600)
HTML(chart.svg)
# Out:
# <svg height="600" width="600" font-family="sans-serif" version="1.1" xmlns="http://www.w3.org/2000/svg"><circle cx="300.0" cy="300.0" r="270.0" fill="#343a40" /><path d="M300.0 300.0 L553.25 206.37 A270.0 270.0 0 0 0 472.5 92.29 Z" fill="#463b44" stroke="#F7F3F0" stroke-width="1" stroke-opacity="1"></path><path d="M300.0 300.0 L472.5 92.29 A270.0 270.0 0 0 0 345.54 33.87 Z" fill="#484943" stroke="#F7F3F0" stroke-width="1" stroke-opacity="1"></path><path d="M300.0 300.0 L345.54 33.87 A270.0 270.0 0 0 0 206.37 46.75 Z" fill="#2f4949" stroke="#F7F3F0" stroke-width="1" stroke-opacity="1"></path><path d="M300.0 300.0 L206.37 46.75 A270.0 270.0 0 0 0 92.29 127.5 Z" fill="#3b4750" stroke="#F7F3F0" stroke-width="1" stroke-opacity="1"></path><path d="M300.0 300.0 L92.29 127.5 A270.0 270.0 0 0 0 33.87 254.46 Z" fill="#463b44" stroke="#F7F3F0" stroke-width="1" stroke-opacity="1"></path><path d="M300.0 300.0 L33.87 254.46 A270.0 270.0 0 0 0 46.75 393.63 Z" fill="#484943" stroke="#F7F3F0" stroke-width="1" stroke-opacity="1"></path><path d="M300.0 300.0 L46.75 393.63 A270.0 270.0 0 0 0 127.5 507.71 Z" fill="#2f4949" stroke="#F7F3F0" stroke-width="1" stroke-opacity="1"></path><path d="M300.0 300.0 L127.5 507.71 A270.0 270.0 0 0 0 254.46 566.13 Z" fill="#3b4750" stroke="#F7F3F0" stroke-width="1" stroke-opacity="1"></path><path d="M300.0 300.0 L254.46 566.13 A270.0 270.0 0 0 0 393.63 553.25 Z" fill="#463b44" stroke="#F7F3F0" stroke-width="1" stroke-opacity="1"></path><path d="M300.0 300.0 L393.63 553.25 A270.0 270.0 0 0 0 507.71 472.5 Z" fill="#484943" stroke="#F7F3F0" stroke-width="1" stroke-opacity="1"></path><path d="M300.0 300.0 L507.71 472.5 A270.0 270.0 0 0 0 566.13 345.54 Z" fill="#2f4949" stroke="#F7F3F0" stroke-width="1" stroke-opacity="1"></path><path d="M300.0 300.0 L566.13 345.54 A270.0 270.0 0 0 0 553.25 206.37 Z" fill="#3b4750" stroke="#F7F3F0" stroke-width="1" stroke-opacity="1"></path><circle cx="300.0" cy="300.0" r="229.5" fill="#343a40" /><path d="M300.0 300.0 L70.5 299.96 A229.5 229.5 0 0 0 96.45 406.01 Z" fill="#463b44" stroke="#F7F3F0" stroke-width="1" stroke-opacity="1"></path><text x="96.74670934464947" y="349.7359260270843" fill="#ef476f" font-size="17.820000000000004" text-anchor="middle" dominant-baseline="central">1</text><path d="M300.0 300.0 L96.45 406.01 A229.5 229.5 0 0 0 178.15 494.48 Z" fill="#484943" stroke="#F7F3F0" stroke-width="1" stroke-opacity="1"></path><text x="146.26877139164426" y="441.95869769255233" fill="#ffd166" font-size="17.820000000000004" text-anchor="middle" dominant-baseline="central">2</text><path d="M300.0 300.0 L178.15 494.48 A229.5 229.5 0 0 0 298.04 529.49 Z" fill="#2f4949" stroke="#F7F3F0" stroke-width="1" stroke-opacity="1"></path><text x="241.3407521164669" y="500.85978974831727" fill="#06d6a0" font-size="17.820000000000004" text-anchor="middle" dominant-baseline="central">3</text><path d="M300.0 300.0 L298.04 529.49 A229.5 229.5 0 0 0 417.24 497.3 Z" fill="#3b4750" stroke="#F7F3F0" stroke-width="1" stroke-opacity="1"></path><text x="354.56360874710276" y="502.01082916639166" fill="#81bce7" font-size="17.820000000000004" text-anchor="middle" dominant-baseline="central">4</text><path d="M300.0 300.0 L417.24 497.3 A229.5 229.5 0 0 0 500.78 411.16 Z" fill="#463b44" stroke="#F7F3F0" stroke-width="1" stroke-opacity="1"></path><text x="450.2044846078006" y="445.6851924654835" fill="#ef476f" font-size="17.820000000000004" text-anchor="middle" dominant-baseline="central">5</text><path d="M300.0 300.0 L500.78 411.16 A229.5 229.5 0 0 0 529.5 300.04 Z" fill="#484943" stroke="#F7F3F0" stroke-width="1" stroke-opacity="1"></path><text x="502.594074221901" y="352.35650475510073" fill="#ffd166" font-size="17.820000000000004" text-anchor="middle" dominant-baseline="central">6</text><path d="M300.0 300.0 L529.5 300.04 A229.5 229.5 0 0 0 503.55 193.99 Z" fill="#2f4949" stroke="#F7F3F0" stroke-width="1" stroke-opacity="1"></path><text x="503.2532906553505" y="250.2640739729157" fill="#06d6a0" font-size= ...

# %%
# Statistics of Celestial Bodies

stats = Stats(data1=mimi, data2=current)
HTML(stats.full_report("html"))
# Out:
# <div class="tabulate distribution"><h4>Element Distribution (MiMi)</h4><table>
# <thead>
# <tr><th>element  </th><th style="text-align: center;"> count </th><th>bodies                                      </th></tr>
# </thead>
# <tbody>
# <tr><td>earth    </td><td style="text-align: center;">   4   </td><td>sun ♉, jupiter ♍, saturn ♍, asc ♍       </td></tr>
# <tr><td>water    </td><td style="text-align: center;">   2   </td><td>moon ♋, uranus ♏                          </td></tr>
# <tr><td>fire     </td><td style="text-align: center;">   4   </td><td>mercury ♈, mars ♌, neptune ♐, asc_node ♌</td></tr>
# <tr><td>air      </td><td style="text-align: center;">   3   </td><td>venus ♊, pluto ♎, mc ♊                   </td></tr>
# </tbody>
# </table></div><div class="tabulate distribution"><h4>Quality Distribution (MiMi)</h4><table>
# <thead>
# <tr><th>quality  </th><th style="text-align: center;"> count </th><th>bodies                                                    </th></tr>
# </thead>
# <tbody>
# <tr><td>fixed    </td><td style="text-align: center;">   4   </td><td>sun ♉, mars ♌, uranus ♏, asc_node ♌                   </td></tr>
# <tr><td>cardinal </td><td style="text-align: center;">   3   </td><td>moon ♋, mercury ♈, pluto ♎                             </td></tr>
# <tr><td>mutable  </td><td style="text-align: center;">   6   </td><td>venus ♊, jupiter ♍, saturn ♍, neptune ♐, asc ♍, mc ♊</td></tr>
# </tbody>
# </table></div><div class="tabulate distribution"><h4>Polarity Distribution (MiMi)</h4><table>
# <thead>
# <tr><th>polarity  </th><th style="text-align: center;"> count </th><th>bodies                                                                 </th></tr>
# </thead>
# <tbody>
# <tr><td>negative  </td><td style="text-align: center;">   6   </td><td>sun ♉, moon ♋, jupiter ♍, saturn ♍, uranus ♏, asc ♍              </td></tr>
# <tr><td>positive  </td><td style="text-align: center;">   7   </td><td>mercury ♈, venus ♊, mars ♌, neptune ♐, pluto ♎, asc_node ♌, mc ♊</td></tr>
# </tbody>
# </table></div><div class="tabulate celestial_body"><h4>Celestial Bodies (MiMi)</h4><table>
# <thead>
# <tr><th>body    </th><th>sign     </th><th style="text-align: center;"> house </th><th>dignity  </th></tr>
# </thead>
# <tbody>
# <tr><td>sun     </td><td>00°♉19&#x27; </td><td style="text-align: center;">   8   </td><td>         </td></tr>
# <tr><td>moon    </td><td>08°♋29&#x27; </td><td style="text-align: center;">  10   </td><td>domicile </td></tr>
# <tr><td>mercury </td><td>08°♈28&#x27; </td><td style="text-align: center;">   8   </td><td>         </td></tr>
# <tr><td>venus   </td><td>15°♊12&#x27; </td><td style="text-align: center;">  10   </td><td>         </td></tr>
# <tr><td>mars    </td><td>26°♌59&#x27; </td><td style="text-align: center;">  12   </td><td>         </td></tr>
# <tr><td>jupiter </td><td>00°♍17&#x27;℞</td><td style="text-align: center;">  12   </td><td>detriment</td></tr>
# <tr><td>saturn  </td><td>21°♍03&#x27;℞</td><td style="text-align: center;">   1   </td><td>         </td></tr>
# <tr><td>uranus  </td><td>24°♏31&#x27;℞</td><td style="text-align: center;">   3   </td><td>         </td></tr>
# <tr><td>neptune </td><td>22°♐29&#x27;℞</td><td style="text-align: center;">   4   </td><td>         </td></tr>
# <tr><td>pluto   </td><td>20°♎06&#x27;℞</td><td style="text-align: center;">   2   </td><td>         </td></tr>
# <tr><td>asc_node</td><td>26°♌03&#x27;℞</td><td style="text-align: center;">  12   </td><td>         </td></tr>
# <tr><td>asc     </td><td>09°♍42&#x27; </td><td style="text-align: center;">   1   </td><td>         </td></tr>
# <tr><td>mc      </td><td>09°♊13&#x27; </td><td style="text-align: center;">  10   </td><td>         </td></tr>
# </tbody>
# </table></div><div class="tabulate house"><h4>Houses (MiMi)</h4><table>
# <thead>
# <tr><th style="text-align: center;"> house </th><th>cusp    </th><th>ruler  </th><th>ruler sign  </th><th style="text-align: center;"> ruler house </th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: center;">   1   </td><td>09°♍41&#x27;</td><td>mercury</td><td>♈          </td><td style="text-align: center;">      8      </td></tr>
# <tr><td style="text-align: center;">   2   </td><td>07°♎13&#x27;</td><td>venus  </td><td>♊          </td><td style="text-align: center;">     10      </td></tr>
# <tr><td style="text-align: center;">   3   </td><td>07°♏38&#x27;</td><td>pluto  </td><td>♎          </td><td style="text-align: center;">      2      </td></tr>
# <tr><td style="text-align: center;">   4   </td><td>09°♐13&#x27;</td><td>jupiter</td><td>♍          </td><td style="text-align: center;">     12      </td></tr>
# <tr><td style="text-align: center;">   5   </td><td>10°♑25&#x27;</td><td>saturn </td><td>♍          </td><td style="text-align: center;">      1      </td></tr>
# <tr><td style="text-align: center;">   6   </td><td>10°♒44&#x27;</td><td>uranus </td><td>♏          </td><td style="text-align: center;">      3      </td></tr>
# <tr><td style="text-align: center;">   7   </td><td>09°♓41&#x27;</td><td>neptune</td><td>♐          </td><td style="text-align: center;">      4      </td></tr>
# <tr><td style="text-align: center;">   8   </td><td>07°♈13&#x27;</td><td>mars   </td><td>♌          </td><td style="text-align: center;">     12      </td></tr>
# <tr><td style="text-align: center;">   9   </td><td>07°♉38&#x27;</td><td>venus  </td><td>♊          </td><td style="text-align: center;">     10      </td></tr>
# <tr><td style="text-align: center;">  10   </td><td>09°♊13&#x27;</td><td>mercury</td><td>♈          </td><td style="text-align: center;">      8      </td></tr>
# <tr><td style="text-align: center;">  11   </td><td>10°♋25&#x27;</td><td>moon   </td><td>♋          </td><td style="text-align: center;">     10      </td></tr>
# <tr><td style="text-align: center;">  12   </td><td>10°♌44&#x27;</td><td>sun    </td><td>♉          </td><td style="text-align: center;">      8      </td></tr>
# </tbody>
# </table></div><div class="tabulate quadrant"><h4>Quadrants (MiMi)</h4><table>
# <thead>
# <tr><th>quadrant  </th><th style="text-align: center;"> count </th><th>bodies                              </th></tr>
# </thead>
# <tbody>
# <tr><td>1st ◵     </td><td style="text-align: center;">   3   </td><td>saturn, uranus, pluto               </td></tr>
# <tr><td>2nd ◶     </td><td style="text-align: center;">   1   </td><td>neptune                             </td></tr>
# <tr><td>3rd ◷     </td><td style="text-align: center;">   2   </td><td>sun, mercury                        </td></tr>
# <tr><td>4th ◴     </td><td style="text-align: center;">   5   </td><td>moon, venus, mars, jupiter, asc_node</td></tr>
# </tbody>
# </table></div><div class="tabulate hemisphere"><h4>Hemispheres (MiMi)</h4><table>
# <thead>
# <tr><th>hemisphere  </th><th style="text-align: center;"> count </th><th>bodies                                                     </th></tr>
# </thead>
# <tbody>
# <tr><td>←           </td><td style="text-align: center;">   8   </td><td>saturn, uranus, pluto, moon, venus, mars, jupiter, asc_node</td></tr>
# <tr><td>→           </td><td style="text-align: center;">   3   </td><td>neptune, sun, mercury                                      </td></tr>
# <tr><td>↑           </td><td style="text-align: center;">   7   </td><td>sun, mercury, moon, venus, mars, jupiter, asc_node         </td></tr>
# <tr><td>↓           </td><td style="text-align: center;">   4   </td><td>saturn, uranus, pluto, neptune                             </td></tr>
# </tbody>
# </table></div><div class="tabulate data2_celestial_body"><h4>Celestial Bodies of Current in MiMi's chart</h4><table>
# <thead>
# <tr><th>Current  </th><th>sign     </th><th style="text-align: center;"> house </th></tr>
# </thead>
# <tbody>
# <tr><td>sun      </td><td>19°♏26&#x27; </td><td style="text-align: center;">   3   </td></tr>
# <tr><td>moon     </td><td>16°♓43&#x27; </td><td style="text-align: center;">   7   </td></tr>
# <tr><td>mercury  </td><td>11°♐15&#x27; </td><td style="text-align: center;">   4   </td></tr>
# <tr><td>venus    </td><td>29°♐30&#x27; </td><td style="text-align: center;">   4   </td></tr>
# <tr><td>mars     <

# %%
# Monochrome Chart
mimi.config.theme_type = "mono"
chart = Chart(data1=mimi, width=600)
HTML(chart.svg)
# Out:
# <svg height="600" width="600" font-family="sans-serif" version="1.1" xmlns="http://www.w3.org/2000/svg"><circle cx="300.0" cy="300.0" r="270.0" fill="#FFFFFF" /><path d="M300.0 300.0 L553.25 206.37 A270.0 270.0 0 0 0 472.5 92.29 Z" fill="#ffffff" stroke="#888888" stroke-width="1" stroke-opacity="1"></path><path d="M300.0 300.0 L472.5 92.29 A270.0 270.0 0 0 0 345.54 33.87 Z" fill="#ffffff" stroke="#888888" stroke-width="1" stroke-opacity="1"></path><path d="M300.0 300.0 L345.54 33.87 A270.0 270.0 0 0 0 206.37 46.75 Z" fill="#ffffff" stroke="#888888" stroke-width="1" stroke-opacity="1"></path><path d="M300.0 300.0 L206.37 46.75 A270.0 270.0 0 0 0 92.29 127.5 Z" fill="#ffffff" stroke="#888888" stroke-width="1" stroke-opacity="1"></path><path d="M300.0 300.0 L92.29 127.5 A270.0 270.0 0 0 0 33.87 254.46 Z" fill="#ffffff" stroke="#888888" stroke-width="1" stroke-opacity="1"></path><path d="M300.0 300.0 L33.87 254.46 A270.0 270.0 0 0 0 46.75 393.63 Z" fill="#ffffff" stroke="#888888" stroke-width="1" stroke-opacity="1"></path><path d="M300.0 300.0 L46.75 393.63 A270.0 270.0 0 0 0 127.5 507.71 Z" fill="#ffffff" stroke="#888888" stroke-width="1" stroke-opacity="1"></path><path d="M300.0 300.0 L127.5 507.71 A270.0 270.0 0 0 0 254.46 566.13 Z" fill="#ffffff" stroke="#888888" stroke-width="1" stroke-opacity="1"></path><path d="M300.0 300.0 L254.46 566.13 A270.0 270.0 0 0 0 393.63 553.25 Z" fill="#ffffff" stroke="#888888" stroke-width="1" stroke-opacity="1"></path><path d="M300.0 300.0 L393.63 553.25 A270.0 270.0 0 0 0 507.71 472.5 Z" fill="#ffffff" stroke="#888888" stroke-width="1" stroke-opacity="1"></path><path d="M300.0 300.0 L507.71 472.5 A270.0 270.0 0 0 0 566.13 345.54 Z" fill="#ffffff" stroke="#888888" stroke-width="1" stroke-opacity="1"></path><path d="M300.0 300.0 L566.13 345.54 A270.0 270.0 0 0 0 553.25 206.37 Z" fill="#ffffff" stroke="#888888" stroke-width="1" stroke-opacity="1"></path><circle cx="300.0" cy="300.0" r="229.5" fill="#FFFFFF" /><path d="M300.0 300.0 L70.5 299.96 A229.5 229.5 0 0 0 96.45 406.01 Z" fill="#ffffff" stroke="#888888" stroke-width="1" stroke-opacity="1"></path><text x="96.74670934464947" y="349.7359260270843" fill="#888888" font-size="17.820000000000004" text-anchor="middle" dominant-baseline="central">1</text><path d="M300.0 300.0 L96.45 406.01 A229.5 229.5 0 0 0 178.15 494.48 Z" fill="#ffffff" stroke="#888888" stroke-width="1" stroke-opacity="1"></path><text x="146.26877139164426" y="441.95869769255233" fill="#888888" font-size="17.820000000000004" text-anchor="middle" dominant-baseline="central">2</text><path d="M300.0 300.0 L178.15 494.48 A229.5 229.5 0 0 0 298.04 529.49 Z" fill="#ffffff" stroke="#888888" stroke-width="1" stroke-opacity="1"></path><text x="241.3407521164669" y="500.85978974831727" fill="#888888" font-size="17.820000000000004" text-anchor="middle" dominant-baseline="central">3</text><path d="M300.0 300.0 L298.04 529.49 A229.5 229.5 0 0 0 417.24 497.3 Z" fill="#ffffff" stroke="#888888" stroke-width="1" stroke-opacity="1"></path><text x="354.56360874710276" y="502.01082916639166" fill="#888888" font-size="17.820000000000004" text-anchor="middle" dominant-baseline="central">4</text><path d="M300.0 300.0 L417.24 497.3 A229.5 229.5 0 0 0 500.78 411.16 Z" fill="#ffffff" stroke="#888888" stroke-width="1" stroke-opacity="1"></path><text x="450.2044846078006" y="445.6851924654835" fill="#888888" font-size="17.820000000000004" text-anchor="middle" dominant-baseline="central">5</text><path d="M300.0 300.0 L500.78 411.16 A229.5 229.5 0 0 0 529.5 300.04 Z" fill="#ffffff" stroke="#888888" stroke-width="1" stroke-opacity="1"></path><text x="502.594074221901" y="352.35650475510073" fill="#888888" font-size="17.820000000000004" text-anchor="middle" dominant-baseline="central">6</text><path d="M300.0 300.0 L529.5 300.04 A229.5 229.5 0 0 0 503.55 193.99 Z" fill="#ffffff" stroke="#888888" stroke-width="1" stroke-opacity="1"></path><text x="503.2532906553505" y="250.2640739729157" fill="#888888" font-size= ...
