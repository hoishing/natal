# %%
from natal import Data, Stats, Chart, Config
from datetime import datetime
from IPython.display import HTML

# %%
# Birth Chart

mimi = Data(
    name = "MiMi",
    city = "Taipei",
    dt = "1980-04-20 14:30",
    config = Config(theme_type="light")
)

chart = Chart(data1=mimi, width=600)
HTML(chart.svg)
# Out:
# <svg height="600" width="600" font-family="Noto Sans Symbols, Cardo, sans-serif" version="1.1" xmlns="http://www.w3.org/2000/svg">
#         <style>
#             @import url("https://fonts.googleapis.com/css2?family=Noto+Sans+Symbols&display=swap&text=♈♉♊♋♌♍♎♏♐♑♒♓☽♃♄♇♆♅⚷⚳⚴⚵⚶☌☍⚹🜂🜄🜁🜃");
#             @import url("https://fonts.googleapis.com/css2?family=Cardo&display=swap&text=♂♀☿☊");
#         </style>
#     <circle cx="300.0" cy="300.0" r="270.0" fill="#FFFDF1" /><path d="M300.0 300.0 L553.25 206.37 A270.0 270.0 0 0 0 472.5 92.29 Z" fill="#ef476f19" stroke="#758492" stroke-width="1" stroke-opacity="1"></path><text x="503.85543994753846" y="155.71548210637584" fill="#ef476f" font-size="22.275000000000002" text-anchor="middle" dominant-baseline="central">♈</text><path d="M300.0 300.0 L472.5 92.29 A270.0 270.0 0 0 0 345.54 33.87 Z" fill="#ffd16619" stroke="#758492" stroke-width="1" stroke-opacity="1"></path><text x="404.4017307474092" y="73.11822215756183" fill="#ffd166" font-size="22.275000000000002" text-anchor="middle" dominant-baseline="central">♉</text><path d="M300.0 300.0 L345.54 33.87 A270.0 270.0 0 0 0 206.37 46.75 Z" fill="#06d6a019" stroke="#758492" stroke-width="1" stroke-opacity="1"></path><text x="276.9736621051004" y="51.313751358966556" fill="#06d6a0" font-size="22.275000000000002" text-anchor="middle" dominant-baseline="central">♊</text><path d="M300.0 300.0 L206.37 46.75 A270.0 270.0 0 0 0 92.29 127.5 Z" fill="#81bce719" stroke="#758492" stroke-width="1" stroke-opacity="1"></path><text x="155.71548210637584" y="96.14456005246157" fill="#81bce7" font-size="22.275000000000002" text-anchor="middle" dominant-baseline="central">♋</text><path d="M300.0 300.0 L92.29 127.5 A270.0 270.0 0 0 0 33.87 254.46 Z" fill="#ef476f19" stroke="#758492" stroke-width="1" stroke-opacity="1"></path><text x="73.11822215756192" y="195.59826925259057" fill="#ef476f" font-size="22.275000000000002" text-anchor="middle" dominant-baseline="central">♌</text><path d="M300.0 300.0 L33.87 254.46 A270.0 270.0 0 0 0 46.75 393.63 Z" fill="#ffd16619" stroke="#758492" stroke-width="1" stroke-opacity="1"></path><text x="51.313751358966556" y="323.0263378948996" fill="#ffd166" font-size="22.275000000000002" text-anchor="middle" dominant-baseline="central">♍</text><path d="M300.0 300.0 L46.75 393.63 A270.0 270.0 0 0 0 127.5 507.71 Z" fill="#06d6a019" stroke="#758492" stroke-width="1" stroke-opacity="1"></path><text x="96.14456005246151" y="444.28451789362407" fill="#06d6a0" font-size="22.275000000000002" text-anchor="middle" dominant-baseline="central">♎</text><path d="M300.0 300.0 L127.5 507.71 A270.0 270.0 0 0 0 254.46 566.13 Z" fill="#81bce719" stroke="#758492" stroke-width="1" stroke-opacity="1"></path><text x="195.5982692525906" y="526.881777842438" fill="#81bce7" font-size="22.275000000000002" text-anchor="middle" dominant-baseline="central">♏</text><path d="M300.0 300.0 L254.46 566.13 A270.0 270.0 0 0 0 393.63 553.25 Z" fill="#ef476f19" stroke="#758492" stroke-width="1" stroke-opacity="1"></path><text x="323.0263378948996" y="548.6862486410334" fill="#ef476f" font-size="22.275000000000002" text-anchor="middle" dominant-baseline="central">♐</text><path d="M300.0 300.0 L393.63 553.25 A270.0 270.0 0 0 0 507.71 472.5 Z" fill="#ffd16619" stroke="#758492" stroke-width="1" stroke-opacity="1"></path><text x="444.28451789362407" y="503.85543994753846" fill="#ffd166" font-size="22.275000000000002" text-anchor="middle" dominant-baseline="central">♑</text><path d="M300.0 300.0 L507.71 472.5 A270.0 270.0 0 0 0 566.13 345.54 Z" fill="#06d6a019" stroke="#758492" stroke-width="1" stroke-opacity="1"></path><text x="526.881777842438" y="404.40173074740943" fill="#06d6a0" font-size="22.275000000000002" text-anchor="middle" dominant-baseline="central">♒</text><path d="M300.0 300.0 L566.13 345.54 A270.0 270.0 0 0 0 553.25 206.37 Z" fill="#81bce719" stroke="#758492" stroke-width="1" stroke-opacity="1"></path><text x="548.6862486410334" y="276.97366210510035" fill="#81bce7" font-size="22.275000000000002" text-anchor="middle" dominant-baseline="central">♓</text><circle cx="300.0" cy="300.0" r="229.5" fill="#FFFDF1" /><path d="M300.0 300.0 L70.5 299.96 A229.5 229.5 0 0 0 96.45 406.01 Z" fill="#ef476f19" stroke="#758492" stroke-width="1" stroke-opacity="1"></path><text x="96.74670934464947" y="349.7359260270843" fill="#ef476f" font-size="17.820000000000004" text-anchor="m ...

# %%
# transit chart
from natal.config import Orb

mimi.config.theme_type="dark"
mimi.config.orb = Orb(conjunction=2, opposition=2, square=2, trine=2, sextile=1)

current = Data(name="Current", city="Taipei", dt=datetime.now())

chart = Chart(data1=mimi, data2=current, width=600)
HTML(chart.svg)
# Out:
# <svg height="600" width="600" font-family="Noto Sans Symbols, Cardo, sans-serif" version="1.1" xmlns="http://www.w3.org/2000/svg">
#         <style>
#             @import url("https://fonts.googleapis.com/css2?family=Noto+Sans+Symbols&display=swap&text=♈♉♊♋♌♍♎♏♐♑♒♓☽♃♄♇♆♅⚷⚳⚴⚵⚶☌☍⚹🜂🜄🜁🜃");
#             @import url("https://fonts.googleapis.com/css2?family=Cardo&display=swap&text=♂♀☿☊");
#         </style>
#     <circle cx="300.0" cy="300.0" r="270.0" fill="#343a40" /><path d="M300.0 300.0 L553.25 206.37 A270.0 270.0 0 0 0 472.5 92.29 Z" fill="#ef476f19" stroke="#F7F3F0" stroke-width="1" stroke-opacity="1"></path><text x="503.85543994753846" y="155.71548210637584" fill="#ef476f" font-size="22.275000000000002" text-anchor="middle" dominant-baseline="central">♈</text><path d="M300.0 300.0 L472.5 92.29 A270.0 270.0 0 0 0 345.54 33.87 Z" fill="#ffd16619" stroke="#F7F3F0" stroke-width="1" stroke-opacity="1"></path><text x="404.4017307474092" y="73.11822215756183" fill="#ffd166" font-size="22.275000000000002" text-anchor="middle" dominant-baseline="central">♉</text><path d="M300.0 300.0 L345.54 33.87 A270.0 270.0 0 0 0 206.37 46.75 Z" fill="#06d6a019" stroke="#F7F3F0" stroke-width="1" stroke-opacity="1"></path><text x="276.9736621051004" y="51.313751358966556" fill="#06d6a0" font-size="22.275000000000002" text-anchor="middle" dominant-baseline="central">♊</text><path d="M300.0 300.0 L206.37 46.75 A270.0 270.0 0 0 0 92.29 127.5 Z" fill="#81bce719" stroke="#F7F3F0" stroke-width="1" stroke-opacity="1"></path><text x="155.71548210637584" y="96.14456005246157" fill="#81bce7" font-size="22.275000000000002" text-anchor="middle" dominant-baseline="central">♋</text><path d="M300.0 300.0 L92.29 127.5 A270.0 270.0 0 0 0 33.87 254.46 Z" fill="#ef476f19" stroke="#F7F3F0" stroke-width="1" stroke-opacity="1"></path><text x="73.11822215756192" y="195.59826925259057" fill="#ef476f" font-size="22.275000000000002" text-anchor="middle" dominant-baseline="central">♌</text><path d="M300.0 300.0 L33.87 254.46 A270.0 270.0 0 0 0 46.75 393.63 Z" fill="#ffd16619" stroke="#F7F3F0" stroke-width="1" stroke-opacity="1"></path><text x="51.313751358966556" y="323.0263378948996" fill="#ffd166" font-size="22.275000000000002" text-anchor="middle" dominant-baseline="central">♍</text><path d="M300.0 300.0 L46.75 393.63 A270.0 270.0 0 0 0 127.5 507.71 Z" fill="#06d6a019" stroke="#F7F3F0" stroke-width="1" stroke-opacity="1"></path><text x="96.14456005246151" y="444.28451789362407" fill="#06d6a0" font-size="22.275000000000002" text-anchor="middle" dominant-baseline="central">♎</text><path d="M300.0 300.0 L127.5 507.71 A270.0 270.0 0 0 0 254.46 566.13 Z" fill="#81bce719" stroke="#F7F3F0" stroke-width="1" stroke-opacity="1"></path><text x="195.5982692525906" y="526.881777842438" fill="#81bce7" font-size="22.275000000000002" text-anchor="middle" dominant-baseline="central">♏</text><path d="M300.0 300.0 L254.46 566.13 A270.0 270.0 0 0 0 393.63 553.25 Z" fill="#ef476f19" stroke="#F7F3F0" stroke-width="1" stroke-opacity="1"></path><text x="323.0263378948996" y="548.6862486410334" fill="#ef476f" font-size="22.275000000000002" text-anchor="middle" dominant-baseline="central">♐</text><path d="M300.0 300.0 L393.63 553.25 A270.0 270.0 0 0 0 507.71 472.5 Z" fill="#ffd16619" stroke="#F7F3F0" stroke-width="1" stroke-opacity="1"></path><text x="444.28451789362407" y="503.85543994753846" fill="#ffd166" font-size="22.275000000000002" text-anchor="middle" dominant-baseline="central">♑</text><path d="M300.0 300.0 L507.71 472.5 A270.0 270.0 0 0 0 566.13 345.54 Z" fill="#06d6a019" stroke="#F7F3F0" stroke-width="1" stroke-opacity="1"></path><text x="526.881777842438" y="404.40173074740943" fill="#06d6a0" font-size="22.275000000000002" text-anchor="middle" dominant-baseline="central">♒</text><path d="M300.0 300.0 L566.13 345.54 A270.0 270.0 0 0 0 553.25 206.37 Z" fill="#81bce719" stroke="#F7F3F0" stroke-width="1" stroke-opacity="1"></path><text x="548.6862486410334" y="276.97366210510035" fill="#81bce7" font-size="22.275000000000002" text-anchor="middle" dominant-baseline="central">♓</text><circle cx="300.0" cy="300.0" r="229.5" fill="#343a40" /><path d="M300.0 300.0 L70.5 299.96 A229.5 229.5 0 0 0 96.45 406.01 Z" fill="#ef476f19" stroke="#F7F3F0" stroke-width="1" stroke-opacity="1"></path><text x="96.74670934464947" y="349.7359260270843" fill="#ef476f" font-size="17.820000000000004" text-anchor="m ...

# %%
# Statistics of Celestial Bodies

stats = Stats(data1=mimi, data2=current)
HTML(stats.full_report("html"))
# Out:
# <div class="tabulate distribution"><h4>Element Distribution (MiMi)</h4><table>
# <thead>
# <tr><th>element  </th><th style="text-align: center;"> count </th><th>bodies                                      </th></tr>
# </thead>
# <tbody>
# <tr><td>earth    </td><td style="text-align: center;">   4   </td><td>sun ♉, jupiter ♍, saturn ♍, asc ♍       </td></tr>
# <tr><td>water    </td><td style="text-align: center;">   2   </td><td>moon ♋, uranus ♏                          </td></tr>
# <tr><td>fire     </td><td style="text-align: center;">   4   </td><td>mercury ♈, mars ♌, neptune ♐, asc_node ♌</td></tr>
# <tr><td>air      </td><td style="text-align: center;">   3   </td><td>venus ♊, pluto ♎, mc ♊                   </td></tr>
# </tbody>
# </table></div><div class="tabulate distribution"><h4>Quality Distribution (MiMi)</h4><table>
# <thead>
# <tr><th>quality  </th><th style="text-align: center;"> count </th><th>bodies                                                    </th></tr>
# </thead>
# <tbody>
# <tr><td>fixed    </td><td style="text-align: center;">   4   </td><td>sun ♉, mars ♌, uranus ♏, asc_node ♌                   </td></tr>
# <tr><td>cardinal </td><td style="text-align: center;">   3   </td><td>moon ♋, mercury ♈, pluto ♎                             </td></tr>
# <tr><td>mutable  </td><td style="text-align: center;">   6   </td><td>venus ♊, jupiter ♍, saturn ♍, neptune ♐, asc ♍, mc ♊</td></tr>
# </tbody>
# </table></div><div class="tabulate distribution"><h4>Polarity Distribution (MiMi)</h4><table>
# <thead>
# <tr><th>polarity  </th><th style="text-align: center;"> count </th><th>bodies                                                                 </th></tr>
# </thead>
# <tbody>
# <tr><td>negative  </td><td style="text-align: center;">   6   </td><td>sun ♉, moon ♋, jupiter ♍, saturn ♍, uranus ♏, asc ♍              </td></tr>
# <tr><td>positive  </td><td style="text-align: center;">   7   </td><td>mercury ♈, venus ♊, mars ♌, neptune ♐, pluto ♎, asc_node ♌, mc ♊</td></tr>
# </tbody>
# </table></div><div class="tabulate celestial_body"><h4>Celestial Bodies (MiMi)</h4><table>
# <thead>
# <tr><th>body    </th><th>sign     </th><th style="text-align: center;"> house </th></tr>
# </thead>
# <tbody>
# <tr><td>sun     </td><td>00°♉19&#x27; </td><td style="text-align: center;">   8   </td></tr>
# <tr><td>moon    </td><td>08°♋29&#x27; </td><td style="text-align: center;">  10   </td></tr>
# <tr><td>mercury </td><td>08°♈28&#x27; </td><td style="text-align: center;">   8   </td></tr>
# <tr><td>venus   </td><td>15°♊12&#x27; </td><td style="text-align: center;">  10   </td></tr>
# <tr><td>mars    </td><td>26°♌59&#x27; </td><td style="text-align: center;">  12   </td></tr>
# <tr><td>jupiter </td><td>00°♍17&#x27;℞</td><td style="text-align: center;">  12   </td></tr>
# <tr><td>saturn  </td><td>21°♍03&#x27;℞</td><td style="text-align: center;">   1   </td></tr>
# <tr><td>uranus  </td><td>24°♏31&#x27;℞</td><td style="text-align: center;">   3   </td></tr>
# <tr><td>neptune </td><td>22°♐29&#x27;℞</td><td style="text-align: center;">   4   </td></tr>
# <tr><td>pluto   </td><td>20°♎06&#x27;℞</td><td style="text-align: center;">   2   </td></tr>
# <tr><td>asc_node</td><td>26°♌03&#x27;℞</td><td style="text-align: center;">  12   </td></tr>
# <tr><td>asc     </td><td>09°♍42&#x27; </td><td style="text-align: center;">   1   </td></tr>
# <tr><td>mc      </td><td>09°♊13&#x27; </td><td style="text-align: center;">  10   </td></tr>
# </tbody>
# </table></div><div class="tabulate house"><h4>Houses (MiMi)</h4><table>
# <thead>
# <tr><th style="text-align: center;"> house </th><th>sign    </th><th>ruler  </th><th>ruler sign  </th><th style="text-align: center;"> ruler house </th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: center;">   1   </td><td>09°♍41&#x27;</td><td>mercury</td><td>♈          </td><td style="text-align: center;">      8      </td></tr>
# <tr><td style="text-align: center;">   2   </td><td>07°♎13&#x27;</td><td>venus  </td><td>♊          </td><td style="text-align: center;">     10      </td></tr>
# <tr><td style="text-align: center;">   3   </td><td>07°♏38&#x27;</td><td>pluto  </td><td>♎          </td><td style="text-align: center;">      2      </td></tr>
# <tr><td style="text-align: center;">   4   </td><td>09°♐13&#x27;</td><td>jupiter</td><td>♍          </td><td style="text-align: center;">     12      </td></tr>
# <tr><td style="text-align: center;">   5   </td><td>10°♑25&#x27;</td><td>saturn </td><td>♍          </td><td style="text-align: center;">      1      </td></tr>
# <tr><td style="text-align: center;">   6   </td><td>10°♒44&#x27;</td><td>uranus </td><td>♏          </td><td style="text-align: center;">      3      </td></tr>
# <tr><td style="text-align: center;">   7   </td><td>09°♓41&#x27;</td><td>neptune</td><td>♐          </td><td style="text-align: center;">      4      </td></tr>
# <tr><td style="text-align: center;">   8   </td><td>07°♈13&#x27;</td><td>mars   </td><td>♌          </td><td style="text-align: center;">     12      </td></tr>
# <tr><td style="text-align: center;">   9   </td><td>07°♉38&#x27;</td><td>venus  </td><td>♊          </td><td style="text-align: center;">     10      </td></tr>
# <tr><td style="text-align: center;">  10   </td><td>09°♊13&#x27;</td><td>mercury</td><td>♈          </td><td style="text-align: center;">      8      </td></tr>
# <tr><td style="text-align: center;">  11   </td><td>10°♋25&#x27;</td><td>moon   </td><td>♋          </td><td style="text-align: center;">     10      </td></tr>
# <tr><td style="text-align: center;">  12   </td><td>10°♌44&#x27;</td><td>sun    </td><td>♉          </td><td style="text-align: center;">      8      </td></tr>
# </tbody>
# </table></div><div class="tabulate quadrant"><h4>Quadrants (MiMi)</h4><table>
# <thead>
# <tr><th>quadrant  </th><th style="text-align: center;"> count </th><th>bodies                              </th></tr>
# </thead>
# <tbody>
# <tr><td>1st ◵     </td><td style="text-align: center;">   3   </td><td>saturn, uranus, pluto               </td></tr>
# <tr><td>2nd ◶     </td><td style="text-align: center;">   1   </td><td>neptune                             </td></tr>
# <tr><td>3rd ◷     </td><td style="text-align: center;">   2   </td><td>sun, mercury                        </td></tr>
# <tr><td>4th ◴     </td><td style="text-align: center;">   5   </td><td>moon, venus, mars, jupiter, asc_node</td></tr>
# </tbody>
# </table></div><div class="tabulate hemisphere"><h4>Hemispheres (MiMi)</h4><table>
# <thead>
# <tr><th>hemisphere  </th><th style="text-align: center;"> count </th><th>bodies                                                     </th></tr>
# </thead>
# <tbody>
# <tr><td>←           </td><td style="text-align: center;">   8   </td><td>saturn, uranus, pluto, moon, venus, mars, jupiter, asc_node</td></tr>
# <tr><td>→           </td><td style="text-align: center;">   3   </td><td>neptune, sun, mercury                                      </td></tr>
# <tr><td>↑           </td><td style="text-align: center;">   7   </td><td>sun, mercury, moon, venus, mars, jupiter, asc_node         </td></tr>
# <tr><td>↓           </td><td style="text-align: center;">   4   </td><td>saturn, uranus, pluto, neptune                             </td></tr>
# </tbody>
# </table></div><div class="tabulate data2_celestial_body"><h4>Celestial Bodies of Current in MiMi's chart</h4><table>
# <thead>
# <tr><th>Current  </th><th>sign     </th><th style="text-align: center;"> house </th></tr>
# </thead>
# <tbody>
# <tr><td>sun      </td><td>01°♏27&#x27; </td><td style="text-align: center;">   2   </td></tr>
# <tr><td>moon     </td><td>02°♌05&#x27; </td><td style="text-align: center;">  11   </td></tr>
# <tr><td>mercury  </td><td>16°♏23&#x27; </td><td style="text-align: center;">   3   </td></tr>
# <tr><td>venus    </td><td>07°♐56&#x27; </td><td style="text-align: center;">   3   </td></tr>
# <tr><td>mars     </td><td>25°♋54&#x27; </td><td style="text-align: center;">  11   </td></tr>
# <tr><td>jupiter  </td><td>20°♊57&#x27;℞</td><td style="text-align: center;">  10   </td></tr>
# <tr><td>saturn   </td><td>13°♓07&#x27;℞</td><td style="text-align: center;">   7

# %%
# Monochrome Chart
mimi.config.theme_type = "mono"
chart = Chart(data1=mimi, width=600)
HTML(chart.svg)
# Out:
# <svg height="600" width="600" font-family="Noto Sans Symbols, Cardo, sans-serif" version="1.1" xmlns="http://www.w3.org/2000/svg">
#         <style>
#             @import url("https://fonts.googleapis.com/css2?family=Noto+Sans+Symbols&display=swap&text=♈♉♊♋♌♍♎♏♐♑♒♓☽♃♄♇♆♅⚷⚳⚴⚵⚶☌☍⚹🜂🜄🜁🜃");
#             @import url("https://fonts.googleapis.com/css2?family=Cardo&display=swap&text=♂♀☿☊");
#         </style>
#     <circle cx="300.0" cy="300.0" r="270.0" fill="white" /><path d="M300.0 300.0 L553.25 206.37 A270.0 270.0 0 0 0 472.5 92.29 Z" fill="#88888800" stroke="#888888" stroke-width="1" stroke-opacity="1"></path><text x="503.85543994753846" y="155.71548210637584" fill="#888888" font-size="22.275000000000002" text-anchor="middle" dominant-baseline="central">♈</text><path d="M300.0 300.0 L472.5 92.29 A270.0 270.0 0 0 0 345.54 33.87 Z" fill="#88888800" stroke="#888888" stroke-width="1" stroke-opacity="1"></path><text x="404.4017307474092" y="73.11822215756183" fill="#888888" font-size="22.275000000000002" text-anchor="middle" dominant-baseline="central">♉</text><path d="M300.0 300.0 L345.54 33.87 A270.0 270.0 0 0 0 206.37 46.75 Z" fill="#88888800" stroke="#888888" stroke-width="1" stroke-opacity="1"></path><text x="276.9736621051004" y="51.313751358966556" fill="#888888" font-size="22.275000000000002" text-anchor="middle" dominant-baseline="central">♊</text><path d="M300.0 300.0 L206.37 46.75 A270.0 270.0 0 0 0 92.29 127.5 Z" fill="#88888800" stroke="#888888" stroke-width="1" stroke-opacity="1"></path><text x="155.71548210637584" y="96.14456005246157" fill="#888888" font-size="22.275000000000002" text-anchor="middle" dominant-baseline="central">♋</text><path d="M300.0 300.0 L92.29 127.5 A270.0 270.0 0 0 0 33.87 254.46 Z" fill="#88888800" stroke="#888888" stroke-width="1" stroke-opacity="1"></path><text x="73.11822215756192" y="195.59826925259057" fill="#888888" font-size="22.275000000000002" text-anchor="middle" dominant-baseline="central">♌</text><path d="M300.0 300.0 L33.87 254.46 A270.0 270.0 0 0 0 46.75 393.63 Z" fill="#88888800" stroke="#888888" stroke-width="1" stroke-opacity="1"></path><text x="51.313751358966556" y="323.0263378948996" fill="#888888" font-size="22.275000000000002" text-anchor="middle" dominant-baseline="central">♍</text><path d="M300.0 300.0 L46.75 393.63 A270.0 270.0 0 0 0 127.5 507.71 Z" fill="#88888800" stroke="#888888" stroke-width="1" stroke-opacity="1"></path><text x="96.14456005246151" y="444.28451789362407" fill="#888888" font-size="22.275000000000002" text-anchor="middle" dominant-baseline="central">♎</text><path d="M300.0 300.0 L127.5 507.71 A270.0 270.0 0 0 0 254.46 566.13 Z" fill="#88888800" stroke="#888888" stroke-width="1" stroke-opacity="1"></path><text x="195.5982692525906" y="526.881777842438" fill="#888888" font-size="22.275000000000002" text-anchor="middle" dominant-baseline="central">♏</text><path d="M300.0 300.0 L254.46 566.13 A270.0 270.0 0 0 0 393.63 553.25 Z" fill="#88888800" stroke="#888888" stroke-width="1" stroke-opacity="1"></path><text x="323.0263378948996" y="548.6862486410334" fill="#888888" font-size="22.275000000000002" text-anchor="middle" dominant-baseline="central">♐</text><path d="M300.0 300.0 L393.63 553.25 A270.0 270.0 0 0 0 507.71 472.5 Z" fill="#88888800" stroke="#888888" stroke-width="1" stroke-opacity="1"></path><text x="444.28451789362407" y="503.85543994753846" fill="#888888" font-size="22.275000000000002" text-anchor="middle" dominant-baseline="central">♑</text><path d="M300.0 300.0 L507.71 472.5 A270.0 270.0 0 0 0 566.13 345.54 Z" fill="#88888800" stroke="#888888" stroke-width="1" stroke-opacity="1"></path><text x="526.881777842438" y="404.40173074740943" fill="#888888" font-size="22.275000000000002" text-anchor="middle" dominant-baseline="central">♒</text><path d="M300.0 300.0 L566.13 345.54 A270.0 270.0 0 0 0 553.25 206.37 Z" fill="#88888800" stroke="#888888" stroke-width="1" stroke-opacity="1"></path><text x="548.6862486410334" y="276.97366210510035" fill="#888888" font-size="22.275000000000002" text-anchor="middle" dominant-baseline="central">♓</text><circle cx="300.0" cy="300.0" r="229.5" fill="white" /><path d="M300.0 300.0 L70.5 299.96 A229.5 229.5 0 0 0 96.45 406.01 Z" fill="#88888800" stroke="#888888" stroke-width="1" stroke-opacity="1"></path><text x="96.74670934464947" y="349.7359260270843" fill="#888888" font-size="17.820000000000004" text-anchor="middl ...
